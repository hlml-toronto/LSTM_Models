# %%
import lyricsgenius
client_token = 's86ExsILIhrEXrTfQmePOYXJ6jPT9KACHQ22dXs960suWEpwa4HQwUn56AB5Gsx7'
genius = lyricsgenius.Genius(client_token)

#don't need to run this again, already saved the lyrics
#artist = genius.search_artist("Lil Pump", sort="title")
#artist.save_lyrics()
# Out:
# Searching for songs by Lil' Pump...
#
# Changing artist name to 'Lil Pump'
# Song 1: "1 Choppa 2 Choppa*"
# Song 2: "30's"
# Song 3: "70 Nigga"
# Song 4: "Aight"
# Song 5: "At the Door"
# Song 6: "Back"
# Song 7: "Bad Bitch"
# Song 8: "Be Like Me"
# Song 9: "Bitch I Think I Have Swag"
# Song 10: "Boppin’"
# Song 11: "Boss"
# Song 12: "Broke My Wrist"
# Song 13: "Butterfly Doors"
# Song 14: "BUT THEN I POPPED XAN"
# Song 15: "Coupe"
# Song 16: "Crazy"
# Song 17: "Designer"
# Song 18: "Designer (Remix)"
# Song 19: "Drop Out"
# Song 20: "D Rose"
# Song 21: "DR. PHIL"
# Song 22: "Drug Addicts"
# Song 23: "Drum$tick"
# Song 24: "Elementary"
# Song 25: "ESSKEETIT"
# Song 26: "Fasho Fasho"
# Song 27: "FIJI"
# Song 28: "Finesse the Pack"
# Song 29: "Flex Like Ouu"
# Song 30: "Foreign"
# Song 31: "Fuck J. Cole"
# Song 32: "Gang Shit"
# Song 33: "Get"
# Song 34: "Gucci Gang"
# Song 35: "Gucci Gang (English Remix)"
# Song 36: "Gucci Gang (Mega Remix)"
# Song 37: "Gucci Gang (Spanish Remix)"
# Song 38: "Had"
# Song 39: "Hello (2016)"
# Song 40: "House Arrest"
# Song 41: "Iced Out"
# Song 42: "Ignorant"
# Song 43: "I’m Just Fucked Up"
# Song 44: "ION"
# Song 45: "King Of The Trap*"
# Song 46: "Left Cheek, Right Cheek"
# Song 47: "Like I’m Spanish (Whippin’)"
# Song 48: "Like Legos"
# Song 49: "Lil Pump"
# Song 50: "Molly"
# Song 51: "Movin"
# Song 52: "Multi Millionaire"
# Song 53: "New Bob Dylan*"
# Song 54: "Next"
# Song 55: "No Way"
# Song 56: "Nu Uh"
# Song 57: "Obama"
# Song 58: "Off White"
# Song 59: "On Fleek"
# Song 60: "On Larry"
# Song 61: "Ou Ou Ou"
# Song 62: "Pinky Ring"
# Song 63: "Racks on Racks"
# Song 64: "Rick Rubin*"
# Song 65: "She Luv The Way"
# Song 66: "SLATT*"
# Song 67: "Smoke My Dope"
# Song 68: "Stripper Name"
# Song 69: "TAKE"
# Song 70: "THEY SUSPENDED MY TWITTER"
# Song 71: "Tie My Shoe*"
# Song 72: "Too Much Ice"
# Song 73: "Trapspot"
# Song 74: "Untitled Freestyle"
# Song 75: "Untitled Freestyle 2"
# Song 76: "Valentines Day"
# Song 77: "Vroom Vroom Vroom"
# Song 78: "Welcome to the Party"
# Song 79: "What Happened"
# Song 80: "What’s Yo Numbah"
# Song 81: "What U Sayin’"
# Song 82: "Whitney"
# Song 83: "Who da Fuq is"
# Song 84: "Who Dat"
# Song 85: "Who Dat (2017)"
# Song 86: "XXL Freshman Freestyle: Lil Pump"
# Song 87: "You Ain’t Livin’ Life Like Me*"
# Song 88: "Youngest Flexer"
# Done. Found 88 songs.

# %%
import pandas as pd
import numpy as np
import json
import glob

#empty data frame

#get the song lyric names
lyric_files = glob.glob("*.json")
#
#load the lyrics into a dataframe
df = pd.DataFrame()
for i in range(len(lyric_files)):
    predf = pd.read_json(lyric_files[i],orient='index',typ='series')
    df = df.append(predf.songs)
    
#i dont think we care about the rest
data = df[['title','lyrics']]
data.sample(3)

data.to_csv('lyrics_titles_AutoPump.csv')
